# %%
import pilpy as p
import glob

# %%
all_images = glob.glob("img/*.jpg")

# %%
#detect images in folder and save into array
all_images
all1 = p.np.array(all_images)

#count no of images
count_images = 0
for o in all1:
    count_images += 1
count_images
# Out:
# 5

# %%
# it will contain all images
main = p.np.zeros((count_images,200,200,3))

# %%
a =0
for i in all_images:
    b = p.image(all1[a],"array",200,200)
    main[a,] = b
    a += 1

main
# Out:
# array([[[[ 47.,  38.,  31.],
#          [144., 139., 135.],
#          [ 94.,  81.,  73.],
#          ...,
#          [ 36.,  34.,  37.],
#          [ 53.,  48.,  44.],
#          [ 84.,  67.,  59.]],
#
#         [[ 48.,  39.,  30.],
#          [ 61.,  52.,  43.],
#          [ 36.,  35.,  30.],
#          ...,
#          [ 45.,  40.,  36.],
#          [ 53.,  45.,  42.],
#          [ 76.,  58.,  48.]],
#
#         [[ 51.,  41.,  32.],
#          [ 70.,  58.,  46.],
#          [ 78.,  60.,  50.],
#          ...,
#          [ 48.,  43.,  39.],
#          [ 66.,  55.,  51.],
#          [ 84.,  66.,  56.]],
#
#         ...,
#
#         [[208., 208., 200.],
#          [205., 206., 198.],
#          [194., 195., 189.],
#          ...,
#          [236., 236., 236.],
#          [236., 236., 236.],
#          [236., 236., 236.]],
#
#         [[211., 212., 206.],
#          [210., 211., 206.],
#          [215., 214., 210.],
#          ...,
#          [234., 234., 234.],
# ...

# %%
p.info("image")
# Out:
#         ------------------------------------------------------------------------------
#         | image function:                                                            |
#         ------------------------------------------------------------------------------
#         | image function contains 4 parameters                                       |
#         | 1 is required                                                              |
#         | 3 are optional                                                             |
#         |                                                                            |
#         | 1 parameter :- image path & name.                                          |
#         | 2 parameter :- img or array (ask return result in form of image or array). |
#         | 3 parameter :- height of an image.                                         |
#         | 4 parameter :- width of an image                                           |
# ...
